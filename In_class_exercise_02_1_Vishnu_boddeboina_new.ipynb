# %% [markdown]
# ## The third In-class-exercise (02/08/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
COVID19 brought many changes to people's lives. One of them is the oximeter. 
Many people, including myself, have started buying it to monitor their health.
I did my research to understand the usage and went through a few user reviews and ratings to find the most common issues associated with the oxymeter. 
Now, I would like to use more data and get the technology support to identify common problems associated with it.

Research question: Identify common issues around oximeter

Data: 
There are numerous manufacturers of oximeters on e-commerce websites. I would like to pick the product:
Zacurate Pro Series 500DL Fingertip Pulse Oximeter. It has over 175k reviews. 
As I am interested in issues around the product, I would like to collect data of review title, user rating, review text, and time of the review. 

How many data needed- 
In my understanding 1000 samples od data is sufficient to gain strong knowledge on users complaints for the product.

Data collection - 

Data can be collected using web scraping and interested in stuying the product: 'Zacurate Pro Series 500DL Fingertip Pulse Oximeter', from Amazon website.
Steps to collect data - 
  1. Use Web scraping techinque, extract data from the web document by traversing the dom. This can be done using python language and beautiful soup package.
  2. Link for the reviews - https://www.amazon.com/Zacurate-Fingertip-Oximeter-Saturation-Batteries/product-reviews/B07PQ8WTC4/ref=cm_cr_getr_d_paging_btm_next_3?ie=UTF8&reviewerType=all_reviews&pageNumber=3. 
  3. This product has 175591 reviews and can extract as many reviews as needed by looping through the pages. However, I would need 1000 reviews to get required knowledge information from the revirews.
  4. beautiful soup helps to parse DOM and get the data like : review title, rating, review text, time of the review
  5. At the end, I will save the data into .csv or .xlsx file for data analysis 


'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

# import libraries
from bs4 import BeautifulSoup
import requests
import urllib.request
import re
import pandas as pd


# headers to open the link

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0',
    'Accept-Language': 'en-US, en;q=0.5'
}


r_titles = []
r_ratings = []
r_text=[]
r_dates=[]
for pg_num in range(1,150):
  r_url = f'https://www.amazon.com/Zacurate-Fingertip-Oximeter-Saturation-Batteries/product-reviews/B07PQ8WTC4/ref=cm_cr_arp_d_paging_btm_next_{str(pg_num)}?ie=UTF8&reviewerType=all_reviews&pageNumber={str(pg_num)}'
 
  # Launch the page
  page = requests.get(r_url, headers=headers)
  # read page content
  soup = BeautifulSoup(page.content,'html.parser')

  # Select all title elemets
  review_titles = soup.find_all('a',class_='review-title-content')
  
  # Extract title text from the dom element
  for t in range(len(review_titles)):
    r_titles.append(review_titles[t].get_text().strip())

  # Select all rating dom elements
  rating_dom = soup.find_all('i',class_='review-rating')
  
  # Extract ratings from the dom element
  for r in range(2,len(rating_dom)):
    r_ratings.append(rating_dom[r].get_text().strip())  
  
   # Select all rating dom elements
  review_text_dom= soup.find_all('span',class_='review-text-content')
  
  # Extract review text text from the dom element
  for rt in range(0,len(review_text_dom)):
    r_text.append(review_text_dom[rt].get_text().strip())


# Create a data frame 
df_reviews = pd.DataFrame({
    'Title' : r_titles,
    'Rating': r_ratings,
    'Review': r_text
})
print(f'Shape of the data frame: {df_reviews.shape}')
df_reviews
# Out:
# Shape of the data frame: (1490, 3)
#                                                   Title  ...                                             Review
# 0     Zacurate Oximeter vs. MiBest: Which is best in...  ...  In this uncertain Covid era, we learned it was...
# 1                                   Slow and unreliable  ...  I am a retired doctor and just purchased two p...
# 2     Very inaccurate reading - led to uncessary eme...  ...  I'm a physician.  I bought the device to have ...
# 3                                       Waste of money!  ...  I was hoping this would be a good product, but...
# 4                                Pulse & Oxygen display  ...  Great, easy to understand instructions and the...
# ...                                                 ...  ...                                                ...
# 1485                         Works well and easy to use  ...  Seems like it works pretty well. I had difficu...
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# Note: Google is blocking my IP and returning No results if I make more requests. 
# Here I was able to get 600 articles details. If I tried to make more requests, google detects my activity as suspicious and blocking my IP.
# The process for pulling articles details is same.
# Big value in the for loop will search in more pages and gives more articles.
# You code here (Please add comments in the code):
from bs4 import BeautifulSoup
import requests
import urllib.request 
import re
import pandas as pd
df_articles = pd.DataFrame()


# headers to open the link

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0',
    'Accept-Language': 'en-US, en;q=0.5'
}
for pg_num in range(1, 300):
  # URL with search string
  url = f'https://scholar.google.com/scholar?start={str(pg_num)}&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022'
  print(url)
  # Launch the url
  pg = requests.get(url, headers=headers)

  # Read DOM using BeautifulSoup
  soup = BeautifulSoup(pg.content,'html.parser')

  # Select each article from search results
  for article in soup.select('[data-lid]'):
    # get title text
    title = article.select_one('.gs_rt').text
    # get journal details 
    journal = article.select_one('.gs_a').text

    # get publisher details 
    publisher= article.select('a')[0].get_text()

    pub_info = article.find_all('div',class_='gs_a')[0].get_text()
    
    # extract authors
    authors= pub_info.split('-')[0]
    abstract= article.find_all('div',class_='gs_rs')[0].get_text()

    # Extract year from publisher info
    b_year = re.findall(r'\d+', pub_info)
    
    info = list(map(int, b_year))
    year = str(info)[1:-1]

    # Add data to data frame
    df_articles = df_articles.append(pd.DataFrame({'Title': title, 'Journal': journal, 'Publisher':publisher, 'Year': year, 'Authors': authors, 'Abstract': abstract}, index=[0]))

print(f'Shape of the data frame: {df_articles.shape}')
df_articles
# Out:
# https://scholar.google.com/scholar?start=1&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=2&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=3&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=4&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=5&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=6&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=7&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=8&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# https://scholar.google.com/scholar?start=9&q=information+retrieval&hl=en&as_sdt=0,44&as_ylo=2012&as_yhi=2022
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):

# I have pulled the data from twitter platform
# Steps:
# sign up for the twitter developer portal and create a project. 
# use API key and API secret to authenticate my self and communicate with twitter api

# !pip install tweepy
import tweepy

# Twitter API keys
api_key = "****"
api_secret = "***"

# Authentication
authentication = tweepy.OAuthHandler(api_key, api_secret)
api = tweepy.API(authentication, wait_on_rate_limit=True)
tweets_list = []

# %%
# I have used the hash tag to pull the tweets
query = "#fridayfeeling -filter:retweets"

# get tweets from the API
tweets = tweepy.Cursor(api.search,
              q=query,
              lang="en",
              since="2022-01-02").items(1000)


tweets_list = [tweet for tweet in tweets]
print("Total Tweets fetched are:", len(tweets_list))
# Out:
# Total Tweets fetched are: 1000

# %%
# Store tweets in a data frame
import pandas as pd
df_tweets = pd.DataFrame()

for t in tweets_list:
    try:
        text = api.get_status(id=t.id, tweet_mode='extended').full_text
    except:
        pass
    df_tweets = df_tweets.append(pd.DataFrame({'user_name': t.user.name, 'posted_time': t.created_at, 'text': text}, index=[0]))
    # tweets_df = tweets_df.reset_index(drop=True)

# show the dataframe
print(f'Shape of the data frame: {df_tweets.shape}')
df_tweets.head()
# Out:
# Shape of the data frame: (1000, 3)
#                                   user_name  ...                                               text
# 0                                      Meta  ...  Who's impersonating who? @meta @facebookapp #f...
# 0                       Susan Wilking Horan  ...  @eleesha @ionacrv @nancybarfield @JolieBStudio...
# 0                         Your Writing Muse  ...  You secure a copy editor and proofreader, an e...
# 0  AFC_Jame #Undefeated #Invincible⚪️🔴🎗 #14  ...  Me Saturday Morning                Me Monday m...
# 0                         Political Tribune  ...  Mark Meadows Is Groveling Again, Seems Despera...
#
# [5 rows x 3 columns]
